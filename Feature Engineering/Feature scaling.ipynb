# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MaxAbsScaler, RobustScaler, PowerTransformer, FunctionTransformer
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Wine_Data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  \
# 0           0    14.23        1.71  2.43          15.6        127
# 1           1    13.20        1.78  2.14          11.2        100
# 2           2    13.16        2.36  2.67          18.6        101
# 3           3    14.37        1.95  2.50          16.8        113
# 4           4    13.24        2.59  2.87          21.0        118
#
#    Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color_Intensity   Hue  OD280  Proline
# 0             5.64  1.04   3.92     1065
# 1             4.38  1.05   3.40     1050
# 2             5.68  1.03   3.17     1185
# 3             7.80  0.86   3.45     1480
# 4             4.32  1.04   2.93      735

# %%
data = df[['Alcohol', 'Magnesium']]

# %%
data.head()
# Out:
#    Alcohol  Magnesium
# 0    14.23        127
# 1    13.20        100
# 2    13.16        101
# 3    14.37        113
# 4    13.24        118

# %% [markdown]
# # Normalization / min max scalar

# %%
scalar = MinMaxScaler()

# %%
data['mm_alcohol'] = scalar.fit_transform(df[['Alcohol']])

# %%
data.head()
# Out:
#    Alcohol  Magnesium  mm_alcohol
# 0    14.23        127    0.842105
# 1    13.20        100    0.571053
# 2    13.16        101    0.560526
# 3    14.37        113    0.878947
# 4    13.24        118    0.581579

# %% [markdown]
# # Standardization

# %%
standard = StandardScaler()

# %%
data['std_Alcohol'] = standard.fit_transform(data[['Alcohol']])

# %%
data['Alcohol'] = df.Alcohol

# %%
data.head()
# Out:
#    Alcohol  Magnesium  mm_alcohol  std_Alcohol
# 0    14.23        127    0.842105     1.518613
# 1    13.20        100    0.571053     0.246290
# 2    13.16        101    0.560526     0.196879
# 3    14.37        113    0.878947     1.691550
# 4    13.24        118    0.581579     0.295700

# %% [markdown]
# # Log transformation

# %%
log = FunctionTransformer(np.log1p, validate=True)  # np.log1p is used for log(1 + x) to handle zeros in the data
data['Log_Alcohol'] = log.fit_transform(data[['Alcohol']])

# %%
data['Log_Alcohol'] = np.log(data['Alcohol'])

# %%
data.head()
# Out:
#    Alcohol  Magnesium  mm_alcohol  std_Alcohol  Log_Alcohol
# 0    14.23        127    0.842105     1.518613     2.655352
# 1    13.20        100    0.571053     0.246290     2.580217
# 2    13.16        101    0.560526     0.196879     2.577182
# 3    14.37        113    0.878947     1.691550     2.665143
# 4    13.24        118    0.581579     0.295700     2.583243

# %% [markdown]
# # Power tranformations

# %%
power = PowerTransformer()

# %%
data['pow_Alcohol'] = power.fit_transform(df[['Alcohol']])

# %%
data.head()
# Out:
#    Alcohol  Magnesium  mm_alcohol  std_Alcohol  Log_Alcohol  pow_Alcohol
# 0    14.23        127    0.842105     1.518613     2.655352     1.530388
# 1    13.20        100    0.571053     0.246290     2.580217     0.238381
# 2    13.16        101    0.560526     0.196879     2.577182     0.188751
# 3    14.37        113    0.878947     1.691550     2.665143     1.708049
# 4    13.24        118    0.581579     0.295700     2.583243     0.288052

# %% [markdown]
# # Alternative method power tranformation/ Box-Cox

# %%
power_transformer = PowerTransformer(method='box-cox')

# %%
data['box_cox_Alcohol'] = power_transformer.fit_transform(df[['Alcohol']])

# %%
data.head()
# Out:
#    Alcohol  Magnesium  mm_alcohol  std_Alcohol  Log_Alcohol  pow_Alcohol  \
# 0    14.23        127    0.842105     1.518613     2.655352     1.530388
# 1    13.20        100    0.571053     0.246290     2.580217     0.238381
# 2    13.16        101    0.560526     0.196879     2.577182     0.188751
# 3    14.37        113    0.878947     1.691550     2.665143     1.708049
# 4    13.24        118    0.581579     0.295700     2.583243     0.288052
#
#    robust_alcohol  box_cox_Alcohol
# 0        0.897338         1.529934
# 1        0.114068         0.238692
# 2        0.083650         0.189069
# 3        1.003802         1.707400
# 4        0.144487         0.288354

# %% [markdown]
# # Robust Scalar

# %%
robust = RobustScaler()

# %%
data['robust_alcohol'] = robust.fit_transform(df[['Alcohol']])

# %%
data.head()
# Out:
#    Alcohol  Magnesium  mm_alcohol  std_Alcohol  Log_Alcohol  pow_Alcohol  \
# 0    14.23        127    0.842105     1.518613     2.655352     1.530388
# 1    13.20        100    0.571053     0.246290     2.580217     0.238381
# 2    13.16        101    0.560526     0.196879     2.577182     0.188751
# 3    14.37        113    0.878947     1.691550     2.665143     1.708049
# 4    13.24        118    0.581579     0.295700     2.583243     0.288052
#
#    robust_alcohol
# 0        0.897338
# 1        0.114068
# 2        0.083650
# 3        1.003802
# 4        0.144487

# %% [markdown]
# # Box-Cox technique

# %%
data.head()
# Out:
#    Alcohol  Magnesium  mm_alcohol  std_Alcohol  Log_Alcohol  pow_Alcohol  \
# 0    14.23        127    0.842105     1.518613     2.655352     1.530388
# 1    13.20        100    0.571053     0.246290     2.580217     0.238381
# 2    13.16        101    0.560526     0.196879     2.577182     0.188751
# 3    14.37        113    0.878947     1.691550     2.665143     1.708049
# 4    13.24        118    0.581579     0.295700     2.583243     0.288052
#
#    robust_alcohol  box_cox_Alcohol
# 0        0.897338         1.529934
# 1        0.114068         0.238692
# 2        0.083650         0.189069
# 3        1.003802         1.707400
# 4        0.144487         0.288354
