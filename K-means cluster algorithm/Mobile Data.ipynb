# %%
# !pip install numpy==1.26.3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy==1.26.3 in c:\users\user\appdata\roaming\python\python312\site-packages (1.26.3)

# %%
import pandas as pd 
import numpy as np 
import matplotlib as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('mobile_phone_dataset.csv')

# %%
df.head()
# Out:
#    Battery  Screen_Size  RAM  Storage  Price
# 0     4000          6.1    4       64    299
# 1     4500          6.5    6      128    399
# 2     5000          6.7    8      256    699
# 3     3000          5.8    4       32    199
# 4     3500          6.0    4       64    249

# %%
df.describe()
# Out:
#            Battery  Screen_Size        RAM     Storage        Price
# count    30.000000    30.000000  30.000000   30.000000    30.000000
# mean   4176.666667     6.256667   6.033333  140.800000   489.333333
# std     626.805438     0.404870   2.619336  124.532339   278.895399
# min    3000.000000     5.500000   3.000000   32.000000   199.000000
# 25%    3625.000000     6.000000   4.000000   64.000000   269.000000
# 50%    4150.000000     6.200000   5.500000  128.000000   374.000000
# 75%    4700.000000     6.600000   8.000000  128.000000   699.000000
# max    5200.000000     6.900000  12.000000  512.000000  1099.000000

# %%
x = df[['Battery', 'Screen_Size', 'RAM', 'Storage']] 
y = df['Price']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_regressor = KNeighborsRegressor(n_neighbors=3)

# %%
knn_regressor.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
y_pred = knn_regressor.predict(x_test)

# %%
y_test = y_test.reset_index(drop=True)
pd.DataFrame({'Actual_Price': y_test, 'Predicted_Price': y_pred})
# Out:
#    Actual_Price  Predicted_Price
# 0           449       415.666667
# 1           999       799.000000
# 2           349       349.000000
# 3           649       565.666667
# 4           299       349.000000
# 5           699       799.000000
